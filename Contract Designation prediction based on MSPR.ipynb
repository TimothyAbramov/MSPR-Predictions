# %%
# prompt: mount google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Putting data together**

# %%
# prompt: import a .csv dataset

import pandas as pd
mvp_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DL Fall 2024/MSPR predictions/datasets/mvp_train(all terms).csv')
print(mvp_df.head())
# Out:
#    ATTENDANCE  LOW PARTICIPATION  LATE/MISSING ASSIGNMENTS  \
# 0           0                  0                         0
# 1           0                  0                         0
# 2           0                  0                         0
# 3           0                  0                         0
# 4           1                  0                         0
#
#    OTHER ASSIGNMENTS CONCERNS  LOW TEST SCORES  DANGER of UNSATING  \
# 0                           0                0                   0
# 1                           0                1                   1
# 2                           0                0                   0
# 3                           0                0                   0
# 4                           0                0                   0
#
#    DESIGNATION_BINARY
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   0

# %%
mvp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4530 entries, 0 to 4529
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ATTENDANCE                  4530 non-null   int64
#  1   LOW PARTICIPATION           4530 non-null   int64
#  2   LATE/MISSING ASSIGNMENTS    4530 non-null   int64
#  3   OTHER ASSIGNMENTS CONCERNS  4530 non-null   int64
#  4   LOW TEST SCORES             4530 non-null   int64
#  5   DANGER of UNSATING          4530 non-null   int64
#  6   DESIGNATION_BINARY          4530 non-null   int64
# dtypes: int64(7)
# memory usage: 247.9 KB

# %%
# prompt: show distributions for fields in the mvp_df, show distributions in terms of count and percentage

# Calculate counts and percentages for each column
for col in mvp_df.columns:
  print(f"Distribution for column: {col}")
  counts = mvp_df[col].value_counts()
  percentages = (counts / len(mvp_df)) * 100
  distribution_df = pd.DataFrame({'Count': counts, 'Percentage': percentages})
  print(distribution_df)
  print("-" * 20)
# Out:
# Distribution for column: ATTENDANCE
#             Count  Percentage
# ATTENDANCE
# 0            3913   86.379691
# 1             441    9.735099
# 2             117    2.582781
# 3              48    1.059603
# 4              10    0.220751
# 5               1    0.022075
# --------------------
# Distribution for column: LOW PARTICIPATION
#                    Count  Percentage
# LOW PARTICIPATION
# 0                   3881   85.673289
# 1                    529   11.677704
# 2                     98    2.163355
# 3                     22    0.485651
# --------------------
# Distribution for column: LATE/MISSING ASSIGNMENTS
#                           Count  Percentage
# LATE/MISSING ASSIGNMENTS
# 0                          3331   73.532009
# 1                           791   17.461369
# 2                           281    6.203091
# 3                           109    2.406181
# 4                            17    0.375276
# 5                             1    0.022075
# --------------------
# Distribution for column: OTHER ASSIGNMENTS CONCERNS
#                             Count  Percentage
# OTHER ASSIGNMENTS CONCERNS
# 0                            4041   89.205298
# 1                             435    9.602649
# 2                              48    1.059603
# 3                               6    0.132450
# --------------------
# Distribution for column: LOW TEST SCORES
#                  Count  Percentage
# LOW TEST SCORES
# 0                 3850   84.988962
# 1                  554   12.229581
# 2                  116    2.560706
# 3                   10    0.220751
# --------------------
# Distribution for column: DANGER of UNSATING
#                     Count  Percentage
# DANGER of UNSATING
# 0                    3849   84.966887
# 1                     495   10.927152
# 2                     132    2.913907
# 3                      45    0.993377
# 4                       8    0.176600
# 5                       1    0.022075
# --------------------
# Distribution for column: DESIGNATION_BINARY
#                     Count  Percentage
# DESIGNATION_BINARY
# 1                    4113   90.794702
# 0                     417    9.205298
# --------------------

# %% [markdown]
# **Stratified sampling for train, val, and test data**

# %%
# prompt: Split mvp_df into train, validation, and test. Use stratified splitting to maintain class balance across sets.

from sklearn.model_selection import train_test_split

train_df, temp_df = train_test_split(mvp_df, test_size=0.3, stratify=mvp_df['DESIGNATION_BINARY'], random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, stratify=temp_df['DESIGNATION_BINARY'], random_state=42)

print("Train set shape:", train_df.shape)
print("Validation set shape:", val_df.shape)
print("Test set shape:", test_df.shape)
# Out:
# Train set shape: (3171, 7)
# Validation set shape: (679, 7)
# Test set shape: (680, 7)

# %%
# prompt: Show distributions of DESIGNATION_BINARY in train_df, val_df, and test_df

def show_distribution(df, name):
    print(f"Distribution for {name}:")
    counts = df['DESIGNATION_BINARY'].value_counts()
    percentages = (counts / len(df)) * 100
    distribution_df = pd.DataFrame({'Count': counts, 'Percentage': percentages})
    print(distribution_df)
    print("-" * 20)

show_distribution(train_df, "train_df")
show_distribution(val_df, "val_df")
show_distribution(test_df, "test_df")
# Out:
# Distribution for train_df:
#                     Count  Percentage
# DESIGNATION_BINARY
# 1                    2879   90.791548
# 0                     292    9.208452
# --------------------
# Distribution for val_df:
#                     Count  Percentage
# DESIGNATION_BINARY
# 1                     617   90.868925
# 0                      62    9.131075
# --------------------
# Distribution for test_df:
#                     Count  Percentage
# DESIGNATION_BINARY
# 1                     617   90.735294
# 0                      63    9.264706
# --------------------

# %%
# prompt: Split train_df into X_train and y_train. Split val_df into X_val and y_val. Split test_df into X_test and y_test.

X_train = train_df.drop('DESIGNATION_BINARY', axis=1)
y_train = train_df['DESIGNATION_BINARY']

X_val = val_df.drop('DESIGNATION_BINARY', axis=1)
y_val = val_df['DESIGNATION_BINARY']

X_test = test_df.drop('DESIGNATION_BINARY', axis=1)
y_test = test_df['DESIGNATION_BINARY']

# %% [markdown]
# **Standartization**

# %%
# prompt: Standardize X_train. Then standardize X_val and X_test. Use from sklearn.preprocessing import StandardScaler

from sklearn.preprocessing import StandardScaler

# Initialize StandardScaler
scaler = StandardScaler()

# Fit on X_train and transform
X_train_scaled = scaler.fit_transform(X_train)

# Transform X_val and X_test using the same scaler
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %%
# prompt: Print mean and std of X_train_scaled, X_val_scaled, and X_test_scaled

import numpy as np

print("Mean of X_train_scaled:", np.mean(X_train_scaled))
print("Standard deviation of X_train_scaled:", np.std(X_train_scaled))

print("Mean of X_val_scaled:", np.mean(X_val_scaled))
print("Standard deviation of X_val_scaled:", np.std(X_val_scaled))

print("Mean of X_test_scaled:", np.mean(X_test_scaled))
print("Standard deviation of X_test_scaled:", np.std(X_test_scaled))
# Out:
# Mean of X_train_scaled: 0.0
# Standard deviation of X_train_scaled: 1.0
# Mean of X_val_scaled: 0.041313408948414024
# Standard deviation of X_val_scaled: 1.0678334789113186
# Mean of X_test_scaled: 0.027231254798653758
# Standard deviation of X_test_scaled: 1.0407539151632823

# %% [markdown]
# **SMOTE (balance classes for label)**

# %%
# prompt: Use SMOTE on X_train and y_train, to fix unbalance in DESIGNATION_BINARY class distribution

#!pip install imbalanced-learn

from imblearn.over_sampling import SMOTE

# Initialize SMOTE
smote = SMOTE(random_state=42)

# Apply SMOTE to the training data
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_scaled, y_train)

print()
print("Shape of X_train_scaled:", X_train_scaled.shape)
print("Shape of y_train:", y_train.shape)

print()
print("Shape of X_train_resampled:", X_train_resampled.shape)
print("Shape of y_train_resampled:", y_train_resampled.shape)

print()
print("Distribution of y_train_resampled:")
print(y_train_resampled.value_counts())
# Out:
# Shape of X_train_scaled: (3171, 6)
# Shape of y_train: (3171,)
#
# Shape of X_train_resampled: (5758, 6)
# Shape of y_train_resampled: (5758,)
#
# Distribution of y_train_resampled:
# DESIGNATION_BINARY
# 1    2879
# 0    2879
# Name: count, dtype: int64

# %% [markdown]
# **Baseline model: Logistic**

# %%
# prompt: Fit a Logistic regression on train data sets, validate on the validation data sets. Record performance metrics for further comparison.

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Initialize and train the Logistic Regression model
logreg_model = LogisticRegression(random_state=42)
logreg_model.fit(X_train_resampled, y_train_resampled)

# Make predictions on the validation set
y_val_pred = logreg_model.predict(X_val_scaled)

# Evaluate the model
accuracy = accuracy_score(y_val, y_val_pred)
precision = precision_score(y_val, y_val_pred)
recall = recall_score(y_val, y_val_pred)
f1 = f1_score(y_val, y_val_pred)
roc_auc = roc_auc_score(y_val, y_val_pred)


print("Logistic Regression Performance Metrics (Validation Set):")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
print(f"ROC AUC: {roc_auc:.4f}")

performance_metrics = {
    'model': 'Logistic Regression',
    'accuracy': accuracy,
    'precision': precision,
    'recall': recall,
    'f1_score': f1,
    'roc_auc': roc_auc
}
# Out:
# Logistic Regression Performance Metrics (Validation Set):
# Accuracy: 0.8262
# Precision: 0.9646
# Recall: 0.8395
# F1-score: 0.8977
# ROC AUC: 0.7665

# %% [markdown]
# **Logistic Model: Tuning**

# %%
# prompt: Use grid search and cross validation for hyperparameter tuning for the Logistic regression. Record performance metrics.

from sklearn.model_selection import GridSearchCV

# Define the parameter grid for Logistic Regression
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],  # Inverse of regularization strength
    'penalty': ['l1', 'l2'],  # Regularization type
    'solver': ['liblinear', 'saga'] # Solvers that support both penalties
}

# Initialize GridSearchCV
grid_search = GridSearchCV(LogisticRegression(random_state=42, max_iter=1000), param_grid, cv=5, scoring='f1', n_jobs=-1)

# Fit the GridSearchCV to the training data
grid_search.fit(X_train_resampled, y_train_resampled)


# Get the best hyperparameters and best model
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_


print("Best Hyperparameters:", best_params)

# Evaluate the best model on the validation set
y_val_pred = best_model.predict(X_val_scaled)

# Calculate performance metrics
accuracy = accuracy_score(y_val, y_val_pred)
precision = precision_score(y_val, y_val_pred)
recall = recall_score(y_val, y_val_pred)
f1 = f1_score(y_val, y_val_pred)
roc_auc = roc_auc_score(y_val, y_val_pred)


print("Logistic Regression Performance Metrics After Tuning (Validation Set):")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
print(f"ROC AUC: {roc_auc:.4f}")

performance_metrics_log_val = {
    'model': 'Tuned Logistic Regression',
    'accuracy': accuracy,
    'precision': precision,
    'recall': recall,
    'f1_score': f1,
    'roc_auc': roc_auc
}

# Evaluate the best model on the test set
y_test_pred = best_model.predict(X_test_scaled)

# Calculate performance metrics
accuracy = accuracy_score(y_test, y_test_pred)
precision = precision_score(y_test, y_test_pred)
recall = recall_score(y_test, y_test_pred)
f1 = f1_score(y_test, y_test_pred)
roc_auc = roc_auc_score(y_test, y_test_pred)


print("Logistic Regression Performance Metrics After Tuning (Testing set):")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
print(f"ROC AUC: {roc_auc:.4f}")

performance_metrics = {
    'model': 'Tuned Logistic Regression',
    'accuracy': accuracy,
    'precision': precision,
    'recall': recall,
    'f1_score': f1,
    'roc_auc': roc_auc
}
# Out:
# Best Hyperparameters: {'C': 0.01, 'penalty': 'l1', 'solver': 'saga'}
# Logistic Regression Performance Metrics After Tuning (Validation Set):
# Accuracy: 0.8424
# Precision: 0.9636
# Recall: 0.8590
# F1-score: 0.9083
# ROC AUC: 0.7682
# Logistic Regression Performance Metrics After Tuning (Testing set):
# Accuracy: 0.8294
# Precision: 0.9596
# Recall: 0.8476
# F1-score: 0.9002
# ROC AUC: 0.7492

# %% [markdown]
# **Neural Network for binary classification**

# %%
# prompt: Fit a Neural Network that would be well suited for binary classification on a relatively small dataset. Fit on train data, evaluate on the validation data. Record performance metrics.

import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Define the model
model = keras.Sequential([
    keras.layers.Dense(32, activation='relu', input_shape=(X_train_resampled.shape[1],)),
    keras.layers.Dropout(0.3),  # Add dropout for regularization
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(X_train_resampled, y_train_resampled, epochs=20, batch_size=32, validation_data=(X_val_scaled, y_val))


# Make predictions on the validation set
y_val_pred_prob = model.predict(X_val_scaled)
y_val_pred = (y_val_pred_prob > 0.5).astype(int) # Convert probabilities to binary predictions

# Evaluate the model (validation set)
accuracy = accuracy_score(y_val, y_val_pred)
precision = precision_score(y_val, y_val_pred)
recall = recall_score(y_val, y_val_pred)
f1 = f1_score(y_val, y_val_pred)
roc_auc = roc_auc_score(y_val, y_val_pred_prob)


print("Neural Network Performance Metrics (Validation Set):")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
print(f"ROC AUC: {roc_auc:.4f}")

performance_metrics = {
    'model': 'Neural Network',
    'accuracy': accuracy,
    'precision': precision,
    'recall': recall,
    'f1_score': f1,
    'roc_auc': roc_auc
}
# Out:
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5945 - loss: 0.7090 - val_accuracy: 0.7172 - val_loss: 0.5916
# Epoch 2/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7614 - loss: 0.5288 - val_accuracy: 0.7850 - val_loss: 0.5202
# Epoch 3/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7785 - loss: 0.5011 - val_accuracy: 0.7894 - val_loss: 0.4830
# Epoch 4/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7785 - loss: 0.5019 - val_accuracy: 0.7791 - val_loss: 0.5229
# Epoch 5/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7951 - loss: 0.4922 - val_accuracy: 0.7953 - val_loss: 0.5001
# Epoch 6/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7851 - loss: 0.5034 - val_accuracy: 0.8056 - val_loss: 0.4943
# Epoch 7/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7851 - loss: 0.5037 - val_accuracy: 0.8041 - val_loss: 0.4985
# Epoch 8/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7865 - loss: 0.4981 - val_accuracy: 0.7923 - val_loss: 0.5076
# Epoch 9/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7890 - loss: 0.4930 - val_accuracy: 0.7968 - val_loss: 0.4954
# Epoch 10/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7816 - loss: 0.5081 - val_accuracy: 0.8085 - val_loss: 0.4797
# Epoch 11/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7923 - loss: 0.4919 - val_accuracy: 0.7909 - val_loss: 0.5002
# Epoch 12/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7811 - loss: 0.5002 - val_accuracy: 0.7909 - val_loss: 0.4967
# Epoch 13/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7931 - loss: 0.4887 - val_accuracy: 0.8085 - val_loss: 0.4886
# Epoch 14/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7899 - loss: 0.4907 - val_accuracy: 0.8085 - val_loss: 0.4952
# Epoch 15/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7901 - loss: 0.4948 - val_accuracy: 0.8085 - val_loss: 0.4778
# Epoch 16/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8016 - loss: 0.4776 - val_accuracy: 0.8085 - val_loss: 0.4809
# Epoch 17/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7866 - loss: 0.4922 - val_accuracy: 0.8085 - val_loss: 0.4775
# Epoch 18/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7900 - loss: 0.4916 - val_accuracy: 0.8085 - val_loss: 0.4780
# Epoch 19/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7803 - loss: 0.4889 - val_accuracy: 0.8085 - val_loss: 0.4616
# Epoch 20/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7998 - loss: 0.4833 - val_accuracy: 0.8085 - val_loss: 0.4828
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Neural Network Performance Metrics (Validation Set):
# Accuracy: 0.8085
# Precision: 0.9638
# Recall: 0.8201
# F1-score: 0.8862
# ROC AUC: 0.8265

# %%
# !pip install scikeras

from sklearn.model_selection import GridSearchCV
from scikeras.wrappers import KerasClassifier
from tensorflow import keras

# Define the parameter grid for the neural network
param_grid = {
    'model__units1': [32, 64, 128],
    'model__units2': [16, 32, 64],
    'model__dropout1': [0.3, 0.5, 0.7],
    'model__dropout2': [0.2, 0.4, 0.6],
    'batch_size': [32],
    'epochs': [30]
}

# Function to create and compile the model
def create_model(units1, units2, dropout1, dropout2, optimizer='adam'):
    model = keras.Sequential([
        keras.layers.Dense(units1, activation='relu', input_shape=(X_train_resampled.shape[1],)),
        keras.layers.Dropout(dropout1),
        keras.layers.Dense(units2, activation='relu'),
        keras.layers.Dropout(dropout2),
        keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=optimizer,
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# Use KerasClassifier for Scikit-learn compatibility
model = KerasClassifier(model=create_model, verbose=0)

# Use GridSearchCV to find the best hyperparameters
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=3, scoring='f1', n_jobs=-1)
grid_result = grid_search.fit(X_train_resampled, y_train_resampled)

# Print the best parameters and score
print(f"Best: {grid_result.best_score_} using {grid_result.best_params_}")

# Evaluate the best model on the validation set
best_model = grid_result.best_estimator_
y_val_pred_prob = best_model.predict_proba(X_val_scaled)
y_val_pred = (y_val_pred_prob > 0.5).astype(int)

# Evaluate the model
# Ensure the labels are binary
# y_val = LabelEncoder().fit_transform(y_val)

# # Compute metrics
# accuracy = accuracy_score(y_val, y_val_pred)
# precision = precision_score(y_val, y_val_pred)
# recall = recall_score(y_val, y_val_pred)
# f1 = f1_score(y_val, y_val_pred)
# roc_auc = roc_auc_score(y_val, y_val_pred_prob)

# # Print metrics
# print("Tuned Neural Network Performance Metrics (Validation Set):")
# print(f"Accuracy: {accuracy:.4f}")
# print(f"Precision: {precision:.4f}")
# print(f"Recall: {recall:.4f}")
# print(f"F1-score: {f1:.4f}")
# print(f"ROC AUC: {roc_auc:.4f}")
# Out:
# Requirement already satisfied: scikeras in /usr/local/lib/python3.10/dist-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (3.5.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.5.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Best: 0.814410197546022 using {'batch_size': 32, 'epochs': 30, 'model__dropout1': 0.3, 'model__dropout2': 0.2, 'model__units1': 128, 'model__units2': 32}

# %%
#more systematic tuning
#1 tune on learning rate
learning_rates = [1e-4, 1e-3, 1e-2, 1e-1]

for lr in learning_rates:
    # Create a new model instance for each learning rate
    model = keras.Sequential([
        keras.layers.Dense(32, activation='relu', input_shape=(X_train_scaled.shape[1],)),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(16, activation='relu'),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(1, activation='sigmoid')
    ])

    # Compile the model with the current learning rate
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=lr),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    # Train the model
    print(f"Training with learning rate: {lr}")
    model.fit(X_train_resampled, y_train_resampled, epochs=10, validation_data=(X_val_scaled, y_val))

    #0.01 learning rate looks like a good bet
# Out:
# Training with learning rate: 0.0001
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5029 - loss: 0.7025 - val_accuracy: 0.6186 - val_loss: 0.7310
# Epoch 2/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.6240 - loss: 0.6541 - val_accuracy: 0.6082 - val_loss: 0.7087
# Epoch 3/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7011 - loss: 0.6190 - val_accuracy: 0.6053 - val_loss: 0.6805
# Epoch 4/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7204 - loss: 0.5953 - val_accuracy: 0.6613 - val_loss: 0.6525
# Epoch 5/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7358 - loss: 0.5677 - val_accuracy: 0.7010 - val_loss: 0.6283
# Epoch 6/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7508 - loss: 0.5533 - val_accuracy: 0.7305 - val_loss: 0.6040
# Epoch 7/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7514 - loss: 0.5331 - val_accuracy: 0.7393 - val_loss: 0.5841
# Epoch 8/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7597 - loss: 0.5318 - val_accuracy: 0.7393 - val_loss: 0.5711
# Epoch 9/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7540 - loss: 0.5258 - val_accuracy: 0.7791 - val_loss: 0.5564
# Epoch 10/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7566 - loss: 0.5220 - val_accuracy: 0.7791 - val_loss: 0.5474
# Training with learning rate: 0.001
# Epoch 1/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6194 - loss: 0.6307 - val_accuracy: 0.7923 - val_loss: 0.5098
# Epoch 2/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7787 - loss: 0.5113 - val_accuracy: 0.7923 - val_loss: 0.5124
# Epoch 3/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7803 - loss: 0.4944 - val_accuracy: 0.8041 - val_loss: 0.4882
# Epoch 4/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7859 - loss: 0.4890 - val_accuracy: 0.8012 - val_loss: 0.4902
# Epoch 5/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7851 - loss: 0.4949 - val_accuracy: 0.8115 - val_loss: 0.4935
# Epoch 6/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7867 - loss: 0.5046 - val_accuracy: 0.8027 - val_loss: 0.5022
# Epoch 7/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7891 - loss: 0.4909 - val_accuracy: 0.8027 - val_loss: 0.4880
# Epoch 8/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7772 - loss: 0.5093 - val_accuracy: 0.8041 - val_loss: 0.4818
# Epoch 9/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7868 - loss: 0.4966 - val_accuracy: 0.8041 - val_loss: 0.4840
# Epoch 10/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7917 - loss: 0.4825 - val_accuracy: 0.8056 - val_loss: 0.4857
# Training with learning rate: 0.01
# Epoch 1/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7535 - loss: 0.5504 - val_accuracy: 0.8027 - val_loss: 0.4913
# Epoch 2/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7913 - loss: 0.4927 - val_accuracy: 0.8247 - val_loss: 0.4263
# Epoch 3/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7834 - loss: 0.4959 - val_accuracy: 0.8012 - val_loss: 0.4399
# Epoch 4/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7951 - loss: 0.4830 - val_accuracy: 0.8115 - val_loss: 0.5216
# Epoch 5/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7905 - loss: 0.4914 - val_accuracy: 0.8130 - val_loss: 0.4481
# Epoch 6/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7991 - loss: 0.4828 - val_accuracy: 0.8027 - val_loss: 0.4929
# Epoch 7/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7855 - loss: 0.4966 - val_accuracy: 0.8174 - val_loss: 0.4252
# Epoch 8/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7992 - loss: 0.4770 - val_accuracy: 0.8233 - val_loss: 0.4312
# Epoch 9/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7913 - loss: 0.4898 - val_accuracy: 0.7953 - val_loss: 0.5297
# Epoch 10/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7987 - loss: 0.4829 - val_accuracy: 0.8233 - val_loss: 0.4461
# Training with learning rate: 0.1
# Epoch 1/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7275 - loss: 0.6006 - val_accuracy: 0.8174 - val_loss: 0.4926
# Epoch 2/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7280 - loss: 0.5740 - val_accuracy: 0.8277 - val_loss: 0.6058
# Epoch 3/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7369 - loss: 0.5557 - val_accuracy: 0.7850 - val_loss: 0.6263
# Epoch 4/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7452 - loss: 0.5454 - val_accuracy: 0.7614 - val_loss: 0.5848
# Epoch 5/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7228 - loss: 0.5621 - val_accuracy: 0.7467 - val_loss: 0.5451
# Epoch 6/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7364 - loss: 0.5450 - val_accuracy: 0.8233 - val_loss: 0.5864
# Epoch 7/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7337 - loss: 0.5558 - val_accuracy: 0.7835 - val_loss: 0.5324
# Epoch 8/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7364 - loss: 0.5543 - val_accuracy: 0.8292 - val_loss: 0.4118
# Epoch 9/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7368 - loss: 0.5567 - val_accuracy: 0.7879 - val_loss: 0.5672
# Epoch 10/10
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7527 - loss: 0.5526 - val_accuracy: 0.6892 - val_loss: 0.5584

# %%
#tuning
#2 dropout rates

import matplotlib.pyplot as plt

# Dropout rates to tune
dropout_rates = [0.2, 0.3, 0.4, 0.5]

# Store results for plotting
history_results = {}

for rate in dropout_rates:
    # Create a new model instance for each dropout rate
    model = keras.Sequential([
        keras.layers.Dense(32, activation='relu', input_shape=(X_train_scaled.shape[1],)),
        keras.layers.Dropout(rate),
        keras.layers.Dense(16, activation='relu'),
        keras.layers.Dropout(rate),
        keras.layers.Dense(1, activation='sigmoid')
    ])

    # Compile the model with accuracy as a metric
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.01),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    # Train the model and store training history
    print(f"Training with dropout rate: {rate}")
    history = model.fit(
        X_train_resampled, y_train_resampled,
        epochs=50,
        validation_data=(X_val_scaled, y_val),
        verbose=0  # Suppress per-epoch output
    )

    # Store history for plotting
    history_results[rate] = history.history

# Plot separate graphs for accuracy for each dropout rate
for rate, history in history_results.items():
    plt.figure(figsize=(8, 6))

    # Plot training and validation accuracy
    plt.plot(history['accuracy'], label='Train Accuracy', linestyle='dashed')
    plt.plot(history['val_accuracy'], label='Validation Accuracy', color='blue')

    # Graph customization
    plt.title(f'Accuracy for Dropout Rate {rate}')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid()

    # Show the graph for the current dropout rate
    plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training with dropout rate: 0.2
# Training with dropout rate: 0.3
# Training with dropout rate: 0.4
# Training with dropout rate: 0.5

# %%
# !pip install scikeras

from sklearn.model_selection import GridSearchCV
from scikeras.wrappers import KerasClassifier
from tensorflow import keras

# Define the parameter grid for the neural network
param_grid = {
    'model__units1': [16, 32, 64, 128],
    'model__units2': [8, 16, 32, 64],
    'model__dropout': [0.2, 0.3, 0.4],
    'batch_size': [16, 32, 64],
    'epochs': [30]
}

# Function to create and compile the model
def create_model(units1, units2, dropout, optimizer='adam'):
    model = keras.Sequential([
        keras.layers.Dense(units1, activation='relu', input_shape=(X_train_resampled.shape[1],)),
        keras.layers.Dropout(dropout),
        keras.layers.Dense(units2, activation='relu'),
        keras.layers.Dropout(dropout),
        keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.01),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# Use KerasClassifier for Scikit-learn compatibility
model = KerasClassifier(model=create_model, verbose=0)

# Use GridSearchCV to find the best hyperparameters
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=3, scoring='f1', n_jobs=-1)
grid_result = grid_search.fit(X_train_resampled, y_train_resampled)

# Print the best parameters and score
print(f"Best: {grid_result.best_score_} using {grid_result.best_params_}")
# Out:
# Collecting scikeras
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (3.5.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.5.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.13.0
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(

# %%
# !pip install scikeras

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV
from scikeras.wrappers import KerasClassifier
from tensorflow import keras

#best model from tuning above (execution failed to some code after the tuning)
model = keras.Sequential([
        keras.layers.Dense(128, activation='relu', input_shape=(X_train_resampled.shape[1],)),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(1, activation='sigmoid')
    ])

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.01),
              loss='binary_crossentropy',metrics=['accuracy'])

model.fit(X_train_resampled, y_train_resampled, epochs=100, batch_size=64, validation_data=(X_val_scaled, y_val))

# Evaluate the best model on the validation set
y_val_pred_prob = model.predict(X_val_scaled)
y_val_pred = (y_val_pred_prob > 0.5).astype(int)

#Evaluate the model
#Ensure the labels are binary
y_val = LabelEncoder().fit_transform(y_val)

# Compute metrics (val)
accuracy = accuracy_score(y_val, y_val_pred)
precision = precision_score(y_val, y_val_pred)
recall = recall_score(y_val, y_val_pred)
f1 = f1_score(y_val, y_val_pred)
roc_auc = roc_auc_score(y_val, y_val_pred_prob)

# Print metrics
print("Tuned Neural Network Performance Metrics (Validation Set):")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
print(f"ROC AUC: {roc_auc:.4f}")

# Evaluate the best model on the validation set
y_test_pred_prob = model.predict(X_test_scaled)
y_test_pred = (y_test_pred_prob > 0.5).astype(int)

#Evaluate the model
#Ensure the labels are binary
y_test = LabelEncoder().fit_transform(y_test)

# Compute metrics (test)
accuracy = accuracy_score(y_test, y_test_pred)
precision = precision_score(y_test, y_test_pred)
recall = recall_score(y_test, y_test_pred)
f1 = f1_score(y_test, y_test_pred)
roc_auc = roc_auc_score(y_test, y_test_pred)

# Print metrics
print("Tuned Neural Network Performance Metrics (Test Set):")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
print(f"ROC AUC: {roc_auc:.4f}")
# Out:
# Requirement already satisfied: scikeras in /usr/local/lib/python3.10/dist-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (3.5.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.5.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7780 - loss: 0.5087 - val_accuracy: 0.8071 - val_loss: 0.4277
# Epoch 2/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7924 - loss: 0.4834 - val_accuracy: 0.7290 - val_loss: 0.5677
# Epoch 3/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7924 - loss: 0.4877 - val_accuracy: 0.7997 - val_loss: 0.4872
# Epoch 4/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8039 - loss: 0.4721 - val_accuracy: 0.8071 - val_loss: 0.5160
# Epoch 5/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8019 - loss: 0.4767 - val_accuracy: 0.7968 - val_loss: 0.4524
# Epoch 6/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7872 - loss: 0.4827 - val_accuracy: 0.8130 - val_loss: 0.5372
# Epoch 7/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8034 - loss: 0.4794 - val_accuracy: 0.7982 - val_loss: 0.4287
# Epoch 8/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7991 - loss: 0.4747 - val_accuracy: 0.8027 - val_loss: 0.5072
# Epoch 9/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7984 - loss: 0.4767 - val_accuracy: 0.8027 - val_loss: 0.4719
# Epoch 10/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7982 - loss: 0.4682 - val_accuracy: 0.8027 - val_loss: 0.5371
# Epoch 11/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7956 - loss: 0.4801 - val_accuracy: 0.8262 - val_loss: 0.4380
# Epoch 12/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8046 - loss: 0.4626 - val_accuracy: 0.8100 - val_loss: 0.5182
# Epoch 13/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7911 - loss: 0.4862 - val_accuracy: 0.7982 - val_loss: 0.5293
# Epoch 14/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8002 - loss: 0.4637 - val_accuracy: 0.8071 - val_loss: 0.4455
# Epoch 15/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8054 - loss: 0.4627 - val_accuracy: 0.7997 - val_loss: 0.5510
# Epoch 16/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8097 - loss: 0.4592 - val_accuracy: 0.8336 - val_loss: 0.4809
# Epoch 17/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8025 - loss: 0.4655 - val_accuracy: 0.8144 - val_loss: 0.4554
# Epoch 18/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7971 - loss: 0.4669 - val_accuracy: 0.8174 - val_loss: 0.4460
# Epoch 19/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8006 - loss: 0.4684 - val_accuracy: 0.8262 - val_loss: 0.5155
# Epoch 20/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8060 - loss: 0.4496 - val_accuracy: 0.8100 - val_loss: 0.5636
# Epoch 21/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7962 - loss: 0.4771 - val_accuracy: 0.8233 - val_loss: 0.4474
# Epoch 22/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7994 - loss: 0.4663 - val_accuracy: 0.8409 - val_loss: 0.4496
# Epoch 23/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8038 - loss: 0.4464 - val_accuracy: 0.8247 - val_loss: 0.4214
# Epoch 24/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8094 - loss: 0.4499 - val_accuracy: 0.8159 - val_loss: 0.4925
# Epoch 25/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8021 - loss: 0.4562 - val_accuracy: 0.8277 - val_loss: 0.4472
# Epoch 26/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8056 - loss: 0.4511 - val_accuracy: 0.8292 - val_loss: 0.4544
# Epoch 27/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8113 - loss: 0.4529 - val_accuracy: 0.8189 - val_loss: 0.4782
# Epoch 28/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8066 - loss: 0.4508 - val_accuracy: 0.8233 - val_loss: 0.4666
# Epoch 29/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8155 - loss: 0.4403 - val_accuracy: 0.8395 - val_loss: 0.4481
# Epoch 30/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8070 - loss: 0.4554 - val_accuracy: 0.8100 - val_loss: 0.5216
# Epoch 31/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8091 - loss: 0.4538 - val_accuracy: 0.8292 - val_loss: 0.4228
# Epoch 32/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7997 - loss: 0.4548 - val_accuracy: 0.8189 - val_loss: 0.4289
# Epoch 33/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8025 - loss: 0.4447 - val_accuracy: 0.8027 - val_loss: 0.4732
# Epoch 34/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8027 - loss: 0.4573 - val_accuracy: 0.8100 - val_loss: 0.4492
# Epoch 35/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8103 - loss: 0.4495 - val_accuracy: 0.8233 - val_loss: 0.4352
# Epoch 36/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8017 - loss: 0.4595 - val_accuracy: 0.8174 - val_loss: 0.4388
# Epoch 37/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8062 - loss: 0.4426 - val_accuracy: 0.8100 - val_loss: 0.4642
# Epoch 38/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8041 - loss: 0.4498 - val_accuracy: 0.8085 - val_loss: 0.4572
# Epoch 39/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8117 - loss: 0.4437 - val_accuracy: 0.8174 - val_loss: 0.5007
# Epoch 40/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8119 - loss: 0.4511 - val_accuracy: 0.8233 - val_loss: 0.4172
# Epoch 41/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8099 - loss: 0.4449 - val_accuracy: 0.8159 - val_loss: 0.4490
# Epoch 42/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8168 - loss: 0.4371 - val_accuracy: 0.8159 - val_loss: 0.4873
# Epoch 43/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8042 - loss: 0.4439 - val_accuracy: 0.8247 - val_loss: 0.4489
# Epoch 44/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8001 - loss: 0.4489 - val_accuracy: 0.8159 - val_loss: 0.4509
# Epoch 45/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8041 - loss: 0.4495 - val_accuracy: 0.8395 - val_loss: 0.4242
# Epoch 46/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8045 - loss: 0.4514 - val_accuracy: 0.8380 - val_loss: 0.4213
# Epoch 47/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8125 - loss: 0.4330 - val_accuracy: 0.8409 - val_loss: 0.4597
# Epoch 48/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8039 - loss: 0.4509 - val_accuracy: 0.8483 - val_loss: 0.4593
# Epoch 49/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8052 - loss: 0.4404 - val_accuracy: 0.8247 - val_loss: 0.4544
# Epoch 50/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8102 - loss: 0.4399 - val_accuracy: 0.8174 - val_loss: 0.5003
# Epoch 51/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8178 - loss: 0.4375 - val_accuracy: 0.8189 - val_loss: 0.4301
# Epoch 52/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8036 - loss: 0.4486 - val_accuracy: 0.8203 - val_loss: 0.4959
# Epoch 53/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8107 - loss: 0.4385 - val_accuracy: 0.8144 - val_loss: 0.4662
# Epoch 54/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8090 - loss: 0.4372 - val_accuracy: 0.8468 - val_loss: 0.4452
# Epoch 55/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8181 - loss: 0.4359 - val_accuracy: 0.8189 - val_loss: 0.4637
# Epoch 56/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8179 - loss: 0.4379 - val_accuracy: 0.8306 - val_loss: 0.4641
# Epoch 57/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8049 - loss: 0.4469 - val_accuracy: 0.8395 - val_loss: 0.4442
# Epoch 58/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8052 - loss: 0.4440 - val_accuracy: 0.8439 - val_loss: 0.4506
# Epoch 59/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8112 - loss: 0.4421 - val_accuracy: 0.8424 - val_loss: 0.4889
# Epoch 60/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8119 - loss: 0.4384 - val_accuracy: 0.8380 - val_loss: 0.4665
# Epoch 61/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8202 - loss: 0.4282 - val_accuracy: 0.8439 - val_loss: 0.4584
# Epoch 62/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8106 - loss: 0.4384 - val_accuracy: 0.8483 - val_loss: 0.4526
# Epoch 63/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8124 - loss: 0.4388 - val_accuracy: 0.8409 - val_loss: 0.4718
# Epoch 64/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8224 - loss: 0.4217 - val_accuracy: 0.8527 - val_loss: 0.4060
# Epoch 65/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8110 - loss: 0.4475 - val_accuracy: 0.8409 - val_loss: 0.4265
# Epoch 66/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8216 - loss: 0.4220 - val_accuracy: 0.8409 - val_loss: 0.5035
# Epoch 67/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8182 - loss: 0.4273 - val_accuracy: 0.8409 - val_loss: 0.4146
# Epoch 68/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8020 - loss: 0.4501 - val_accuracy: 0.8380 - val_loss: 0.4635
# Epoch 69/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8151 - loss: 0.4297 - val_accuracy: 0.8409 - val_loss: 0.4707
# Epoch 70/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8149 - loss: 0.4388 - val_accuracy: 0.8409 - val_loss: 0.4672
# Epoch 71/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8247 - loss: 0.4197 - val_accuracy: 0.8557 - val_loss: 0.4361
# Epoch 72/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8137 - loss: 0.4326 - val_accuracy: 0.8498 - val_loss: 0.4919
# Epoch 73/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8212 - loss: 0.4254 - val_accuracy: 0.8424 - val_loss: 0.4535
# Epoch 74/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8144 - loss: 0.4262 - val_accuracy: 0.8483 - val_loss: 0.4797
# Epoch 75/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8167 - loss: 0.4355 - val_accuracy: 0.8306 - val_loss: 0.5181
# Epoch 76/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8233 - loss: 0.4189 - val_accuracy: 0.8439 - val_loss: 0.4527
# Epoch 77/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8239 - loss: 0.4210 - val_accuracy: 0.8483 - val_loss: 0.4541
# Epoch 78/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8173 - loss: 0.4271 - val_accuracy: 0.8409 - val_loss: 0.4632
# Epoch 79/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8190 - loss: 0.4301 - val_accuracy: 0.8365 - val_loss: 0.4679
# Epoch 80/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8165 - loss: 0.4255 - val_accuracy: 0.8424 - val_loss: 0.4826
# Epoch 81/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8154 - loss: 0.4378 - val_accuracy: 0.8439 - val_loss: 0.4572
# Epoch 82/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8227 - loss: 0.4263 - val_accuracy: 0.8409 - val_loss: 0.5022
# Epoch 83/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8204 - loss: 0.4192 - val_accuracy: 0.8454 - val_loss: 0.5270
# Epoch 84/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8232 - loss: 0.4335 - val_accuracy: 0.8483 - val_loss: 0.4353
# Epoch 85/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8227 - loss: 0.4251 - val_accuracy: 0.8306 - val_loss: 0.4965
# Epoch 86/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8253 - loss: 0.4155 - val_accuracy: 0.8306 - val_loss: 0.4700
# Epoch 87/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8206 - loss: 0.4232 - val_accuracy: 0.8571 - val_loss: 0.4714
# Epoch 88/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8200 - loss: 0.4297 - val_accuracy: 0.8409 - val_loss: 0.5033
# Epoch 89/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8177 - loss: 0.4233 - val_accuracy: 0.8454 - val_loss: 0.4927
# Epoch 90/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8242 - loss: 0.4283 - val_accuracy: 0.8468 - val_loss: 0.5090
# Epoch 91/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8141 - loss: 0.4271 - val_accuracy: 0.8380 - val_loss: 0.5025
# Epoch 92/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8173 - loss: 0.4328 - val_accuracy: 0.8527 - val_loss: 0.5078
# Epoch 93/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8243 - loss: 0.4243 - val_accuracy: 0.8439 - val_loss: 0.5060
# Epoch 94/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8282 - loss: 0.4221 - val_accuracy: 0.8424 - val_loss: 0.5095
# Epoch 95/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8185 - loss: 0.4226 - val_accuracy: 0.8454 - val_loss: 0.4531
# Epoch 96/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8186 - loss: 0.4285 - val_accuracy: 0.8468 - val_loss: 0.4524
# Epoch 97/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8191 - loss: 0.4212 - val_accuracy: 0.8277 - val_loss: 0.4479
# Epoch 98/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8189 - loss: 0.4243 - val_accuracy: 0.8527 - val_loss: 0.4765
# Epoch 99/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8171 - loss: 0.4281 - val_accuracy: 0.8542 - val_loss: 0.4518
# Epoch 100/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8212 - loss: 0.4311 - val_accuracy: 0.8409 - val_loss: 0.4682
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Tuned Neural Network Performance Metrics (Validation Set):
# Accuracy: 0.8409
# Precision: 0.9586
# Recall: 0.8622
# F1-score: 0.9078
# ROC AUC: 0.8033
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Tuned Neural Network Performance Metrics (Test Set):
# Accuracy: 0.8294
# Precision: 0.9497
# Recall: 0.8574
# F1-score: 0.9012
# ROC AUC: 0.7065

# %%
#trying with 3 hidden layers

# !pip install scikeras

from sklearn.model_selection import GridSearchCV
from scikeras.wrappers import KerasClassifier
from tensorflow import keras

# Define the parameter grid for the neural network
param_grid = {
    'model__units1': [16, 32, 64, 128],
    'model__units2': [16, 32, 64, 128],
    'model__units3': [16, 32, 64, 128],
    'model__dropout': [0.2, 0.3],
    'batch_size': [32, 64],
    'epochs': [30]
}

# Function to create and compile the model
def create_model(units1, units2, units3, dropout, optimizer='adam'):
    model = keras.Sequential([
        keras.layers.Dense(units1, activation='relu', input_shape=(X_train_resampled.shape[1],)),
        keras.layers.Dropout(dropout),
        keras.layers.Dense(units2, activation='relu'),
        keras.layers.Dropout(dropout),
        keras.layers.Dense(units3, activation='relu'),
        keras.layers.Dropout(dropout),
        keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.01),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# Use KerasClassifier for Scikit-learn compatibility
model = KerasClassifier(model=create_model, verbose=0)

# Use GridSearchCV to find the best hyperparameters
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=3, scoring='f1', n_jobs=-1)
grid_result = grid_search.fit(X_train_resampled, y_train_resampled)

# Print the best parameters and score
print(f"Best: {grid_result.best_score_} using {grid_result.best_params_}")
# Out:
# Collecting scikeras
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (3.5.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.5.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.13.0
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Best: 0.819534386550993 using {'batch_size': 64, 'epochs': 30, 'model__dropout': 0.2, 'model__units1': 128, 'model__units2': 128, 'model__units3': 32}

# %%
# !pip install scikeras

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV
from scikeras.wrappers import KerasClassifier
from tensorflow import keras

#best model from tuning above (execution failed to some code after the tuning)
model = keras.Sequential([
        keras.layers.Dense(128, activation='relu', input_shape=(X_train_resampled.shape[1],)),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(128, activation='relu'),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(1, activation='sigmoid')
    ])

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.01),
              loss='binary_crossentropy',metrics=['accuracy'])

model.fit(X_train_resampled, y_train_resampled, epochs=100, batch_size=64, validation_data=(X_val_scaled, y_val))

# Evaluate the best model on the validation set
y_val_pred_prob = model.predict(X_val_scaled)
y_val_pred = (y_val_pred_prob > 0.5).astype(int)

#Evaluate the model
#Ensure the labels are binary
y_val = LabelEncoder().fit_transform(y_val)

# Compute metrics (val)
accuracy = accuracy_score(y_val, y_val_pred)
precision = precision_score(y_val, y_val_pred)
recall = recall_score(y_val, y_val_pred)
f1 = f1_score(y_val, y_val_pred)
roc_auc = roc_auc_score(y_val, y_val_pred_prob)

# Print metrics
print("Tuned Neural Network Performance Metrics 3 hidden (Validation Set):")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
print(f"ROC AUC: {roc_auc:.4f}")

# Evaluate the best model on the validation set
y_test_pred_prob = model.predict(X_test_scaled)
y_test_pred = (y_test_pred_prob > 0.5).astype(int)

#Evaluate the model
#Ensure the labels are binary
y_test = LabelEncoder().fit_transform(y_test)

# Compute metrics (test)
accuracy = accuracy_score(y_test, y_test_pred)
precision = precision_score(y_test, y_test_pred)
recall = recall_score(y_test, y_test_pred)
f1 = f1_score(y_test, y_test_pred)
roc_auc = roc_auc_score(y_test, y_test_pred)

# Print metrics
print("Tuned Neural Network Performance Metrics 3 hidden (Test Set):")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
print(f"ROC AUC: {roc_auc:.4f}")
# Out:
# Requirement already satisfied: scikeras in /usr/local/lib/python3.10/dist-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (3.5.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.5.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7546 - loss: 0.5292 - val_accuracy: 0.8027 - val_loss: 0.4942
# Epoch 2/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7997 - loss: 0.4855 - val_accuracy: 0.8100 - val_loss: 0.4290
# Epoch 3/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7935 - loss: 0.4869 - val_accuracy: 0.7953 - val_loss: 0.4369
# Epoch 4/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7977 - loss: 0.4804 - val_accuracy: 0.7761 - val_loss: 0.6227
# Epoch 5/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7935 - loss: 0.4874 - val_accuracy: 0.7820 - val_loss: 0.5548
# Epoch 6/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7926 - loss: 0.4932 - val_accuracy: 0.8130 - val_loss: 0.5589
# Epoch 7/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7971 - loss: 0.4858 - val_accuracy: 0.8277 - val_loss: 0.4601
# Epoch 8/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7933 - loss: 0.4917 - val_accuracy: 0.8115 - val_loss: 0.4402
# Epoch 9/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8005 - loss: 0.4681 - val_accuracy: 0.8159 - val_loss: 0.4892
# Epoch 10/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7897 - loss: 0.4847 - val_accuracy: 0.8218 - val_loss: 0.5080
# Epoch 11/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8070 - loss: 0.4641 - val_accuracy: 0.8321 - val_loss: 0.4414
# Epoch 12/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8159 - loss: 0.4525 - val_accuracy: 0.8115 - val_loss: 0.4796
# Epoch 13/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8034 - loss: 0.4630 - val_accuracy: 0.8144 - val_loss: 0.4452
# Epoch 14/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8151 - loss: 0.4504 - val_accuracy: 0.8424 - val_loss: 0.4369
# Epoch 15/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7986 - loss: 0.4655 - val_accuracy: 0.8321 - val_loss: 0.5343
# Epoch 16/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8101 - loss: 0.4600 - val_accuracy: 0.8424 - val_loss: 0.3932
# Epoch 17/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8142 - loss: 0.4550 - val_accuracy: 0.8071 - val_loss: 0.4389
# Epoch 18/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8048 - loss: 0.4548 - val_accuracy: 0.8189 - val_loss: 0.4554
# Epoch 19/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7913 - loss: 0.4681 - val_accuracy: 0.8277 - val_loss: 0.3967
# Epoch 20/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8050 - loss: 0.4725 - val_accuracy: 0.8012 - val_loss: 0.5056
# Epoch 21/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8081 - loss: 0.4599 - val_accuracy: 0.8336 - val_loss: 0.4745
# Epoch 22/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8056 - loss: 0.4588 - val_accuracy: 0.8203 - val_loss: 0.5004
# Epoch 23/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8034 - loss: 0.4619 - val_accuracy: 0.8483 - val_loss: 0.4951
# Epoch 24/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8164 - loss: 0.4589 - val_accuracy: 0.8262 - val_loss: 0.5069
# Epoch 25/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8049 - loss: 0.4718 - val_accuracy: 0.8100 - val_loss: 0.5872
# Epoch 26/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8088 - loss: 0.4596 - val_accuracy: 0.8292 - val_loss: 0.4680
# Epoch 27/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7980 - loss: 0.4574 - val_accuracy: 0.8262 - val_loss: 0.4595
# Epoch 28/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8128 - loss: 0.4535 - val_accuracy: 0.8306 - val_loss: 0.4472
# Epoch 29/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8201 - loss: 0.4354 - val_accuracy: 0.8336 - val_loss: 0.4994
# Epoch 30/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8059 - loss: 0.4519 - val_accuracy: 0.8395 - val_loss: 0.4251
# Epoch 31/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8090 - loss: 0.4594 - val_accuracy: 0.8424 - val_loss: 0.4135
# Epoch 32/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8050 - loss: 0.4601 - val_accuracy: 0.8130 - val_loss: 0.5520
# Epoch 33/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8056 - loss: 0.4604 - val_accuracy: 0.8277 - val_loss: 0.4907
# Epoch 34/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8054 - loss: 0.4553 - val_accuracy: 0.8351 - val_loss: 0.4419
# Epoch 35/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8051 - loss: 0.4535 - val_accuracy: 0.8468 - val_loss: 0.4979
# Epoch 36/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8078 - loss: 0.4445 - val_accuracy: 0.8557 - val_loss: 0.4780
# Epoch 37/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8156 - loss: 0.4443 - val_accuracy: 0.8336 - val_loss: 0.5382
# Epoch 38/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8115 - loss: 0.4409 - val_accuracy: 0.8292 - val_loss: 0.4857
# Epoch 39/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8140 - loss: 0.4344 - val_accuracy: 0.8292 - val_loss: 0.4829
# Epoch 40/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8211 - loss: 0.4346 - val_accuracy: 0.8454 - val_loss: 0.4910
# Epoch 41/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8154 - loss: 0.4319 - val_accuracy: 0.8247 - val_loss: 0.5133
# Epoch 42/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8112 - loss: 0.4496 - val_accuracy: 0.8321 - val_loss: 0.4510
# Epoch 43/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8166 - loss: 0.4391 - val_accuracy: 0.8174 - val_loss: 0.4958
# Epoch 44/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8252 - loss: 0.4270 - val_accuracy: 0.8292 - val_loss: 0.5238
# Epoch 45/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8128 - loss: 0.4431 - val_accuracy: 0.8292 - val_loss: 0.4847
# Epoch 46/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8137 - loss: 0.4391 - val_accuracy: 0.8336 - val_loss: 0.4885
# Epoch 47/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8110 - loss: 0.4398 - val_accuracy: 0.8233 - val_loss: 0.5402
# Epoch 48/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8058 - loss: 0.4502 - val_accuracy: 0.8306 - val_loss: 0.4878
# Epoch 49/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8086 - loss: 0.4492 - val_accuracy: 0.8601 - val_loss: 0.4571
# Epoch 50/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8115 - loss: 0.4355 - val_accuracy: 0.8189 - val_loss: 0.5480
# Epoch 51/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8060 - loss: 0.4449 - val_accuracy: 0.8380 - val_loss: 0.4827
# Epoch 52/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8086 - loss: 0.4442 - val_accuracy: 0.8439 - val_loss: 0.4844
# Epoch 53/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8152 - loss: 0.4327 - val_accuracy: 0.8306 - val_loss: 0.5215
# Epoch 54/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8092 - loss: 0.4498 - val_accuracy: 0.8218 - val_loss: 0.4831
# Epoch 55/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8119 - loss: 0.4414 - val_accuracy: 0.8174 - val_loss: 0.5308
# Epoch 56/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8137 - loss: 0.4338 - val_accuracy: 0.8292 - val_loss: 0.5229
# Epoch 57/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8180 - loss: 0.4305 - val_accuracy: 0.8262 - val_loss: 0.4984
# Epoch 58/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8158 - loss: 0.4341 - val_accuracy: 0.8365 - val_loss: 0.4980
# Epoch 59/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8240 - loss: 0.4265 - val_accuracy: 0.8439 - val_loss: 0.4647
# Epoch 60/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8224 - loss: 0.4268 - val_accuracy: 0.8292 - val_loss: 0.4905
# Epoch 61/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8191 - loss: 0.4251 - val_accuracy: 0.8439 - val_loss: 0.5017
# Epoch 62/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8113 - loss: 0.4447 - val_accuracy: 0.8292 - val_loss: 0.4861
# Epoch 63/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8104 - loss: 0.4472 - val_accuracy: 0.8262 - val_loss: 0.5191
# Epoch 64/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8089 - loss: 0.4495 - val_accuracy: 0.8409 - val_loss: 0.4881
# Epoch 65/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8155 - loss: 0.4358 - val_accuracy: 0.8277 - val_loss: 0.4886
# Epoch 66/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8055 - loss: 0.4460 - val_accuracy: 0.8513 - val_loss: 0.4547
# Epoch 67/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8176 - loss: 0.4318 - val_accuracy: 0.8292 - val_loss: 0.5620
# Epoch 68/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8158 - loss: 0.4335 - val_accuracy: 0.8262 - val_loss: 0.4905
# Epoch 69/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8267 - loss: 0.4186 - val_accuracy: 0.8454 - val_loss: 0.5112
# Epoch 70/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8187 - loss: 0.4162 - val_accuracy: 0.8365 - val_loss: 0.4851
# Epoch 71/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8164 - loss: 0.4248 - val_accuracy: 0.8468 - val_loss: 0.5175
# Epoch 72/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8174 - loss: 0.4360 - val_accuracy: 0.8468 - val_loss: 0.4810
# Epoch 73/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8144 - loss: 0.4319 - val_accuracy: 0.8306 - val_loss: 0.5229
# Epoch 74/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8304 - loss: 0.4216 - val_accuracy: 0.8292 - val_loss: 0.4913
# Epoch 75/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8200 - loss: 0.4254 - val_accuracy: 0.8321 - val_loss: 0.5128
# Epoch 76/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8192 - loss: 0.4334 - val_accuracy: 0.8174 - val_loss: 0.4632
# Epoch 77/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8167 - loss: 0.4261 - val_accuracy: 0.8454 - val_loss: 0.5062
# Epoch 78/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8122 - loss: 0.4409 - val_accuracy: 0.8542 - val_loss: 0.4684
# Epoch 79/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8296 - loss: 0.4140 - val_accuracy: 0.8247 - val_loss: 0.5582
# Epoch 80/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8334 - loss: 0.4107 - val_accuracy: 0.8365 - val_loss: 0.5689
# Epoch 81/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8166 - loss: 0.4295 - val_accuracy: 0.8306 - val_loss: 0.5062
# Epoch 82/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8110 - loss: 0.4386 - val_accuracy: 0.8468 - val_loss: 0.4620
# Epoch 83/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8150 - loss: 0.4409 - val_accuracy: 0.8498 - val_loss: 0.4432
# Epoch 84/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8295 - loss: 0.4099 - val_accuracy: 0.8365 - val_loss: 0.5098
# Epoch 85/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8184 - loss: 0.4226 - val_accuracy: 0.8542 - val_loss: 0.4802
# Epoch 86/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8195 - loss: 0.4268 - val_accuracy: 0.8557 - val_loss: 0.4573
# Epoch 87/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8156 - loss: 0.4368 - val_accuracy: 0.8218 - val_loss: 0.4997
# Epoch 88/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8183 - loss: 0.4179 - val_accuracy: 0.8527 - val_loss: 0.4853
# Epoch 89/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8164 - loss: 0.4299 - val_accuracy: 0.8262 - val_loss: 0.4969
# Epoch 90/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8213 - loss: 0.4217 - val_accuracy: 0.8233 - val_loss: 0.5318
# Epoch 91/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8242 - loss: 0.4254 - val_accuracy: 0.8527 - val_loss: 0.4793
# Epoch 92/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8299 - loss: 0.4146 - val_accuracy: 0.8306 - val_loss: 0.5256
# Epoch 93/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8258 - loss: 0.4100 - val_accuracy: 0.8454 - val_loss: 0.5511
# Epoch 94/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8131 - loss: 0.4252 - val_accuracy: 0.8395 - val_loss: 0.5166
# Epoch 95/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8273 - loss: 0.4110 - val_accuracy: 0.8306 - val_loss: 0.5102
# Epoch 96/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8181 - loss: 0.4302 - val_accuracy: 0.8351 - val_loss: 0.5641
# Epoch 97/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8209 - loss: 0.4345 - val_accuracy: 0.8351 - val_loss: 0.5326
# Epoch 98/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8230 - loss: 0.4182 - val_accuracy: 0.8351 - val_loss: 0.4973
# Epoch 99/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8257 - loss: 0.4127 - val_accuracy: 0.8483 - val_loss: 0.4348
# Epoch 100/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8167 - loss: 0.4173 - val_accuracy: 0.8233 - val_loss: 0.4930
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Tuned Neural Network Performance Metrics 3 hidden (Validation Set):
# Accuracy: 0.8233
# Precision: 0.9610
# Recall: 0.8395
# F1-score: 0.8962
# ROC AUC: 0.7933
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Tuned Neural Network Performance Metrics 3 hidden (Test Set):
# Accuracy: 0.7971
# Precision: 0.9427
# Recall: 0.8266
# F1-score: 0.8808
# ROC AUC: 0.6673
